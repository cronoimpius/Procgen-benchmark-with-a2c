# %%
# !pip install procgen

# %%
# !pip install --upgrade imageio-ffmpeg

# %%
# %run train.py -a a2c -g starpilot -ne 32 -s 1000000

# %%
# For playing without training, using a saved model
#%run test.py -h
